# %%
import os

# %%
import cv2
import numpy as np

def get_image(fname):
    img = cv2.cvtColor(cv2.imread(fname), cv2.COLOR_BGR2RGB)
    if img is None:
         return None
    img = cv2.resize(img, (224, 224))
    img = img[np.newaxis, :]
    
    return img

# %%
import glob
import os

def process_files(folder_name, start_index=0):
    
    products = []
    index = start_index
    dim = 2048
    xb = np.empty(shape=[0, dim], dtype=np.float32)
    
    for imgfolderpath in glob.glob(folder_name + '/*'):
        productTitle = os.path.basename(imgfolderpath)
    
        for file in glob.glob(imgfolderpath + '/*'):
            try:
                img = get_image(file)
                product = {}
                product['productTitle'] = productTitle
                product['imageFileName'] = file

                # extract features
                features_batch = model.predict([img])
                features = features_batch[0]

                # the Knn algorithm we'll use requires float32 rather than the default float64
                xb = np.append(xb, [features.astype(np.float32)], axis=0)

                products.append(product)
                index += 1
            except:
                print("Something went wrong with the file: " + file)            
    return (products, xb)

# %%
#if not os.path.exists('./dataset-resized'):
#    !curl https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip | jar xv

# %%
from keras.applications.resnet50 import ResNet50
model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling="avg")
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Usrer\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\Usrer\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#products, train_features = process_files('./dataset-resized')
products, train_features = process_files('/solutions/transfer-learning-anime/cropped')

import sklearn
import sklearn.preprocessing

train_features = sklearn.preprocessing.normalize(train_features)

from sklearn.manifold import TSNE
tsne = TSNE(n_components=3).fit_transform(train_features)

import pandas as pd

df = pd.DataFrame(products)
texts = df["imageFileName"]

li, uniques = pd.factorize(df['productTitle'])

li = (li * 99) // (len(uniques) - 1)

import plotly.graph_objs as go
from plotly.offline import plot

scatter = go.Scatter3d(
    x=tsne[:,0],
    y=tsne[:,1],
    z=tsne[:,2],
    mode='markers',
    text=texts,
    marker=dict(
        size=8,
        color=li,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    ))

fig = go.Figure(data=[scatter])

plot(fig, filename='3d-scatter.html')
# Out:
# WARNING:tensorflow:From C:\Users\Usrer\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\1.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\10.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\11.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\12.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\13.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\14.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\15.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\16.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\17.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\18.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\19.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\2.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\20.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\21.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\22.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\23.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\24.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\25.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\26.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\27.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\28.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\29.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\3.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\30.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\31.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\32.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\33.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\34.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\35.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\36.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\4.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\5.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\6.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\7.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\8.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\nishikino_maki\9.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\1.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\10.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\11.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\12.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\13.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\14.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\15.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\16.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\17.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\18.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\19.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\2.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\20.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\21.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\22.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\23.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\24.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\25.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\26.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\27.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\28.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\29.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\3.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\30.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\31.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\32.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\33.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\34.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\35.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\36.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\4.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\5.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\6.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\7.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\8.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\sakurauchi_riko\9.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\1.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\10.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\11.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\12.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\13.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\14.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\15.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\16.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\17.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\18.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\19.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\2.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\20.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\21.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\22.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\23.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\24.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\25.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\26.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\27.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\28.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\29.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\3.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\30.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\31.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\32.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\33.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\34.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\35.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\36.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\4.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\5.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\6.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\7.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\8.jpg
# Something went wrong with the file: /solutions/transfer-learning-anime/cropped\takimoto_hifumi\9.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f3309ecc8a7a> in <module>
#       5 import sklearn.preprocessing
#       6
# ----> 7 train_features = sklearn.preprocessing.normalize(train_features)
#       8
#       9 from sklearn.manifold import TSNE
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\sklearn\preprocessing\_data.py in normalize(X, norm, axis, copy, return_norm)
#    1703
#    1704     X = check_array(X, sparse_format, copy=copy,
# -> 1705                     estimator='the normalize function', dtype=FLOAT_DTYPES)
#    1706     if axis == 0:
#    1707         X = X.T
#
# ~\Anaconda3\envs\tf_gpu\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     584                              " minimum of %d is required%s."
#     585                              % (n_samples, array.shape, ensure_min_samples,
# --> 586                                 context))
#     587
#     588     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2048)) while a minimum of 1 is required by the normalize function.
